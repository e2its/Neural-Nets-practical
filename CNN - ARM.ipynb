# %% [markdown]
# # Dataset ARM: Analísis comparativo de MLPs,CNNs y RNNs para datos basados en Time Series

# %%
import pandas

## Checking tensorflow backend engine
import tensorflow as tf
message = tf.constant('Hello world!')
session = tf.Session()
session.run(message)
import keras.backend as K
print(K.epsilon())

from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout
from keras.layers import Conv2D, MaxPooling2D, Flatten
from keras.utils import to_categorical, plot_model

from numpy import argmax,reshape
# Out:
# 1e-07

# %%
train_df = pandas.read_csv("C:/Users/jose.sanchez/OneDrive/DayF/git/datasets/ARM-Metric-train-TS.csv",encoding="UTF-8")

# %%
test_df = pandas.read_csv("C:/Users/jose.sanchez/OneDrive/DayF/git/datasets/ARM-Metric-test-TS.csv",encoding="UTF-8")

# %%
train_df.groupby('ATYPE').mean()
# Out:
#          avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  avg_rss12_1  \
# ATYPE
# bending  34.249340   0.431254  16.755905   0.733249  23.503262    34.249340
# cyclin   36.743073   2.691047  16.397729   2.990645  17.391611    36.743073
# lyin     39.845100   0.342937   7.264530   0.580750   9.248505    39.845100
# sittin   41.743949   0.401680  14.860580   0.749794  16.095726    41.743949
# standin  43.854565   0.398300  14.776667   0.615786  13.701405    43.854565
# walkin   34.424189   4.337724  15.393813   3.200638  16.018848    34.424189
#
#          var_rss12_1  avg_rss13_1  var_rss13_1  avg_rss23_1  ...  avg_rss12_4  \
# ATYPE                                                        ...
# bending     0.431254    16.755905     0.733249    23.503262  ...    34.030624
# cyclin      2.691047    16.397729     2.990645    17.391611  ...    36.514153
# lyin        0.342937     7.264530     0.580750     9.248505  ...    39.596826
# sittin      0.401680    14.860580     0.749794    16.095726  ...    41.489445
# standin     0.398300    14.776667     0.615786    13.701405  ...    43.575974
# walkin      4.337724    15.393813     3.200638    16.018848  ...    34.205685
#
#          var_rss12_4  avg_rss13_4  var_rss13_4  avg_rss23_4  avg_rss12_5  \
# ATYPE
# bending     0.428355    16.659172     0.727505    23.361322    33.958319
# cyclin      2.671655    16.289588     2.972231    17.278699    36.436510
# lyin        0.341302     7.222859     0.578865     9.176209    39.513958
# sittin      0.399241    14.768017     0.743606    16.006578    41.402354
# standin     0.395777    14.687328     0.611673    13.613623    43.483259
# walkin      4.311599    15.295110     3.181547    15.921445    34.137645
#
#          var_rss12_5  avg_rss13_5  var_rss13_5  avg_rss23_5
# ATYPE
# bending     0.427648    16.626693     0.726028    23.312530
# cyclin      2.667201    16.252897     2.965306    17.244941
# lyin        0.340598     7.208963     0.578144     9.152296
# sittin      0.398618    14.736741     0.742544    15.974439
# standin     0.395032    14.655550     0.610384    13.583375
# walkin      4.302352    15.266241     3.175534    15.886737
#
# [6 rows x 30 columns]

# %%
train_df.groupby('ATYPE').std()
# Out:
#          avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  avg_rss12_1  \
# ATYPE
# bending  12.471234   0.563777   7.089369   0.921850  10.430987    12.471234
# cyclin    3.820435   1.934903   3.608886   1.710640   3.302717     3.820435
# lyin      7.600010   0.377088   3.847469   0.668546   5.113317     7.600010
# sittin    4.158324   0.421325   5.207250   0.867719   5.003480     4.158324
# standin   2.628835   0.374164   3.983268   0.722081   3.907701     2.628835
# walkin    4.812406   2.444056   2.916043   1.624244   3.115523     4.812406
#
#          var_rss12_1  avg_rss13_1  var_rss13_1  avg_rss23_1  ...  avg_rss12_4  \
# ATYPE                                                        ...
# bending     0.563777     7.089369     0.921850    10.430987  ...    12.725044
# cyclin      1.934903     3.608886     1.710640     3.302717  ...     4.795252
# lyin        0.377088     3.847469     0.668546     5.113317  ...     8.214017
# sittin      0.421325     5.207250     0.867719     5.003480  ...     5.276706
# standin     0.374164     3.983268     0.722081     3.907701  ...     4.350781
# walkin      2.444056     2.916043     1.624244     3.115523  ...     5.519083
#
#          var_rss12_4  avg_rss13_4  var_rss13_4  avg_rss23_4  avg_rss12_5  \
# ATYPE
# bending     0.564128     7.181360     0.921409    10.562791    12.807718
# cyclin      1.939090     3.827658     1.722657     3.567922     5.076117
# lyin        0.377359     3.881109     0.669349     5.147825     8.407166
# sittin      0.421247     5.317361     0.866731     5.146924     5.604308
# standin     0.374181     4.128552     0.721632     4.046885     4.785235
# walkin      2.461158     3.151718     1.638863     3.354381     5.730645
#
#          var_rss12_5  avg_rss13_5  var_rss13_5  avg_rss23_5
# ATYPE
# bending     0.564301     7.214285     0.921230    10.606611
# cyclin      1.940822     3.894445     1.726250     3.652404
# lyin        0.377567     3.892634     0.669174     5.159684
# sittin      0.421387     5.354299     0.866980     5.193776
# standin     0.374366     4.178717     0.721755     4.092250
# walkin      2.466088     3.223939     1.643607     3.430036
#
# [6 rows x 30 columns]

# %%
test_df.groupby('ATYPE').mean()
# Out:
#          avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  avg_rss12_1  \
# ATYPE
# bending  34.597288   0.459831  17.382712   0.800169  24.515593    34.597288
# cyclin   37.204545   2.430000  16.170455   2.871970  18.033939    37.204545
# lyin     40.491404   0.392982   7.308246   0.604035  10.464912    40.491404
# sittin   42.306897   0.370000  15.288448   0.866034  16.763276    42.306897
# standin  44.255500   0.428167  14.437167   0.657500  14.179500    44.255500
# walkin   35.790400   4.290000  15.501400   3.628400  16.913200    35.790400
#
#          var_rss12_1  avg_rss13_1  var_rss13_1  avg_rss23_1  ...  avg_rss12_4  \
# ATYPE                                                        ...
# bending     0.459831    17.382712     0.800169    24.515593  ...    34.597288
# cyclin      2.430000    16.170455     2.871970    18.033939  ...    37.204545
# lyin        0.392982     7.308246     0.604035    10.464912  ...    40.491404
# sittin      0.370000    15.288448     0.866034    16.763276  ...    41.531034
# standin     0.428167    14.437167     0.657500    14.179500  ...    44.255500
# walkin      4.290000    15.501400     3.628400    16.913200  ...    35.790400
#
#          var_rss12_4  avg_rss13_4  var_rss13_4  avg_rss23_4  avg_rss12_5  \
# ATYPE
# bending     0.459831    17.382712     0.800169    24.515593    34.597288
# cyclin      2.430000    16.170455     2.871970    18.033939    37.204545
# lyin        0.392982     7.308246     0.604035    10.464912    40.491404
# sittin      0.370000    15.173448     0.830690    16.401207    41.531034
# standin     0.428167    14.437167     0.657500    14.179500    44.255500
# walkin      4.290000    15.501400     3.628400    16.913200    35.790400
#
#          var_rss12_5  avg_rss13_5  var_rss13_5  avg_rss23_5
# ATYPE
# bending     0.459831    17.382712     0.800169    24.515593
# cyclin      2.430000    16.170455     2.871970    18.033939
# lyin        0.392982     7.308246     0.604035    10.464912
# sittin      0.370000    15.173448     0.830690    16.401207
# standin     0.428167    14.437167     0.657500    14.179500
# walkin      4.290000    15.501400     3.628400    16.913200
#
# [6 rows x 30 columns]

# %%
test_df.groupby('ATYPE').std()
# Out:
#          avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  avg_rss12_1  \
# ATYPE
# bending  11.936775   0.423379   6.681963   0.814495   9.677460    11.936775
# cyclin    3.936100   1.907624   3.280253   1.487486   3.265736     3.936100
# lyin      5.823699   0.243787   3.837303   0.636870   4.170597     5.823699
# sittin    3.615483   0.345055   5.476327   0.897030   5.231980     3.615483
# standin   2.255689   0.629720   4.169106   0.854719   4.009013     2.255689
# walkin    4.045297   2.379193   2.376477   1.605666   2.512573     4.045297
#
#          var_rss12_1  avg_rss13_1  var_rss13_1  avg_rss23_1  ...  avg_rss12_4  \
# ATYPE                                                        ...
# bending     0.423379     6.681963     0.814495     9.677460  ...    11.936775
# cyclin      1.907624     3.280253     1.487486     3.265736  ...     3.936100
# lyin        0.243787     3.837303     0.636870     4.170597  ...     5.823699
# sittin      0.345055     5.476327     0.897030     5.231980  ...     6.613111
# standin     0.629720     4.169106     0.854719     4.009013  ...     2.255689
# walkin      2.379193     2.376477     1.605666     2.512573  ...     4.045297
#
#          var_rss12_4  avg_rss13_4  var_rss13_4  avg_rss23_4  avg_rss12_5  \
# ATYPE
# bending     0.423379     6.681963     0.814495     9.677460    11.936775
# cyclin      1.907624     3.280253     1.487486     3.265736     3.936100
# lyin        0.243787     3.837303     0.636870     4.170597     5.823699
# sittin      0.345055     5.724878     0.889920     5.644047     6.613111
# standin     0.629720     4.169106     0.854719     4.009013     2.255689
# walkin      2.379193     2.376477     1.605666     2.512573     4.045297
#
#          var_rss12_5  avg_rss13_5  var_rss13_5  avg_rss23_5
# ATYPE
# bending     0.423379     6.681963     0.814495     9.677460
# cyclin      1.907624     3.280253     1.487486     3.265736
# lyin        0.243787     3.837303     0.636870     4.170597
# sittin      0.345055     5.724878     0.889920     5.644047
# standin     0.629720     4.169106     0.854719     4.009013
# walkin      2.379193     2.376477     1.605666     2.512573
#
# [6 rows x 30 columns]

# %% [markdown]
# ### Normalizamos los datos a mean= 0 y std = 1

# %%
from sklearn.preprocessing import StandardScaler as sc

# %%
encoder = dict()
decoder = dict()
counter = 0

for itera in train_df['ATYPE'].unique():
    encoder[itera] = counter
    decoder[counter] = itera
    counter += 1

# %%
train_df['ATYPE'] = train_df['ATYPE'].apply(lambda x: encoder[x])
test_df['ATYPE'] = test_df['ATYPE'].apply(lambda x: encoder[x])

# %%
train_df['ATYPE']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 41883    5
# 41884    5
# 41885    5
# 41886    5
# 41887    5
# Name: ATYPE, Length: 41888, dtype: int64

# %%
columns = list(train_df.columns)

# %%
print(columns)
# Out:
# ['avg_rss12', 'var_rss12', 'avg_rss13', 'var_rss13', 'avg_rss23', 'ATYPE', 'avg_rss12_1', 'var_rss12_1', 'avg_rss13_1', 'var_rss13_1', 'avg_rss23_1', 'avg_rss12_2', 'var_rss12_2', 'avg_rss13_2', 'var_rss13_2', 'avg_rss23_2', 'avg_rss12_3', 'var_rss12_3', 'avg_rss13_3', 'var_rss13_3', 'avg_rss23_3', 'avg_rss12_4', 'var_rss12_4', 'avg_rss13_4', 'var_rss13_4', 'avg_rss23_4', 'avg_rss12_5', 'var_rss12_5', 'avg_rss13_5', 'var_rss13_5', 'avg_rss23_5']

# %%
columns.remove('ATYPE')

# %%
scaler = sc(copy=False)
scaler.fit(train_df[columns])
# Out:
# StandardScaler(copy=False, with_mean=True, with_std=True)

# %%
train_df[columns] = scaler.transform(train_df[columns])

# %%
test_df[columns] = scaler.transform(test_df[columns])

# %%
train_df.groupby('ATYPE').mean()
# Out:
#        avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  avg_rss12_1  \
# ATYPE
# 0      -0.575895  -0.500222   0.459846  -0.463988   1.106898    -0.575895
# 1      -0.243751   0.601693   0.395822   0.910000   0.226360    -0.243751
# 2       0.169412  -0.543286  -1.236753  -0.556808  -0.946862     0.169412
# 3       0.422323  -0.514642   0.121054  -0.453917   0.039654     0.422323
# 4       0.703439  -0.516291   0.106054  -0.535483  -0.305308     0.703439
# 5      -0.552607   1.404641   0.216370   1.037814   0.028578    -0.552607
#
#        var_rss12_1  avg_rss13_1  var_rss13_1  avg_rss23_1  ...  avg_rss12_4  \
# ATYPE                                                      ...
# 0        -0.500222     0.459846    -0.463988     1.106898  ...    -0.532057
# 1         0.601693     0.395822     0.910000     0.226360  ...    -0.224814
# 2        -0.543286    -1.236753    -0.556808    -0.946862  ...     0.156550
# 3        -0.514642     0.121054    -0.453917     0.039654  ...     0.390691
# 4        -0.516291     0.106054    -0.535483    -0.305308  ...     0.648820
# 5         1.404641     0.216370     1.037814     0.028578  ...    -0.510400
#
#        var_rss12_4  avg_rss13_4  var_rss13_4  avg_rss23_4  avg_rss12_5  \
# ATYPE
# 0        -0.497881     0.450926    -0.461891     1.086105    -0.519429
# 1         0.597723     0.385914     0.904619     0.221410    -0.219566
# 2        -0.540397    -1.208972    -0.552378    -0.930425     0.152806
# 3        -0.512100     0.118262    -0.452089     0.040568     0.381303
# 4        -0.513792     0.104068    -0.532405    -0.299610     0.633094
# 5         1.398655     0.210980     1.032044     0.028466    -0.497730
#
#        var_rss12_5  avg_rss13_5  var_rss13_5  avg_rss23_5
# ATYPE
# 0        -0.497130     0.447944    -0.461080     1.079195
# 1         0.597236     0.382540     0.902363     0.220416
# 2        -0.539667    -1.199911    -0.551124    -0.924980
# 3        -0.511316     0.117253    -0.451024     0.040595
# 4        -0.513068     0.103046    -0.531493    -0.297825
# 5         1.396258     0.209901     1.030366     0.028182
#
# [6 rows x 30 columns]

# %%
test_df.groupby('ATYPE').mean()
# Out:
#        avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  avg_rss12_1  \
# ATYPE
# 0      -0.529551  -0.486287   0.571889  -0.423256   1.252751    -0.529551
# 1      -0.182287   0.474402   0.355196   0.837767   0.318903    -0.182287
# 2       0.255495  -0.518883  -1.228939  -0.542635  -0.771608     0.255495
# 3       0.497303  -0.530090   0.197536  -0.383166   0.135832     0.497303
# 4       0.756840  -0.501727   0.045368  -0.510093  -0.236427     0.756840
# 5      -0.370639   1.381370   0.235601   1.298176   0.157432    -0.370639
#
#        var_rss12_1  avg_rss13_1  var_rss13_1  avg_rss23_1  ...  avg_rss12_4  \
# ATYPE                                                      ...
# 0        -0.486287     0.571889    -0.423256     1.252751  ...    -0.461954
# 1         0.474402     0.355196     0.837767     0.318903  ...    -0.139404
# 2        -0.518883    -1.228939    -0.542635    -0.771608  ...     0.267221
# 3        -0.530090     0.197536    -0.383166     0.135832  ...     0.395836
# 4        -0.501727     0.045368    -0.510093    -0.236427  ...     0.732886
# 5         1.381370     0.235601     1.298176     0.157432  ...    -0.314352
#
#        var_rss12_4  avg_rss13_4  var_rss13_4  avg_rss23_4  avg_rss12_5  \
# ATYPE
# 0        -0.482509     0.578201    -0.417655     1.250194    -0.442113
# 1         0.479702     0.364958     0.843584     0.328774    -0.126634
# 2        -0.515156    -1.193952    -0.537055    -0.747225     0.271078
# 3        -0.526381     0.189579    -0.399076     0.096668     0.396874
# 4        -0.497973     0.060064    -0.504508    -0.219166     0.726535
# 5         1.388107     0.247268     1.304072     0.169452    -0.297746
#
#        var_rss12_5  avg_rss13_5  var_rss13_5  avg_rss23_5
# ATYPE
# 0        -0.481404     0.580228    -0.415937     1.249471
# 1         0.481326     0.368115     0.845533     0.332087
# 2        -0.514069    -1.182539    -0.535359    -0.739198
# 3        -0.525300     0.193665    -0.397354     0.100998
# 4        -0.496877     0.064835    -0.502805    -0.213452
# 5         1.390222     0.251048     1.306105     0.173463
#
# [6 rows x 30 columns]

# %%
x_train = train_df[columns].to_numpy()
y_train = to_categorical(train_df['ATYPE'].to_numpy())

# %%
x_test = test_df[columns].to_numpy()
y_test = to_categorical(test_df['ATYPE'].to_numpy())

# %% [markdown]
# ### Establecemos las estructuras de almacenamiento e iteración de nuestro modelo

# %%
batch_size = [8, 16,32]
epochs = [25]
xfeatures = [64, 256]
hl2 = 128
dropout = [0.05]
kernel_size = [2]
pool_size = 2

# %%
model_result = {'conf': None, 'xaccuracy': None, 'yaccuracy': None, 'xloss' : None, 'yloss' : None, 
                'bepoch' : None, 'baccuracy': None, 'bloss': None}
models_analysis = list()

# %% [markdown]
# ### Importamos las clases Keras necesarias para la creacion de nuestra CNN básica y componemos el modelo.

# %%
x_train = x_train.reshape([-1, 6, 5, 1])
x_test = x_test.reshape([-1, 6, 5, 1])
input_dimension = (x_train.shape[1], x_train.shape[2], 1)
output_dimension = len(train_df['ATYPE'].unique())

# %%
x_train.shape
# Out:
# (41888, 6, 5, 1)

# %%
for hl1 in xfeatures:
    for bs in batch_size:
        for ks in kernel_size:
            for ep in epochs:
                for dp in dropout:
                    # model is a stack of CNN-ReLU-MaxPooling
                    model = Sequential()
                    model.add(Conv2D(filters=hl1, kernel_size=ks, activation='relu', input_shape=input_dimension, data_format='channels_last'))
                    model.add(MaxPooling2D(pool_size))
                    model.add(Flatten())
                    # dropout added as regularizer
                    model.add(Dropout(dp))
                    model.add(Dense(hl2))
                    model.add(Activation('relu'))
                    # output layer is 10-dim one-hot vector
                    model.add(Dense(output_dimension))
                    model.add(Activation('softmax'))

                    #plot_model(model, to_file='img/cnn-mnist-'+str(hl1)+str(hl2)+str(bs)+str(ep)+'.png', show_shapes=True)

                    mr = model_result.copy()
                    mr['conf'] = [hl1, bs, ks, pool_size, ep, dp]            

                    # loss function for one-hot vector
                    # use of adam optimizer
                    # accuracy is a good metric for classification tasks
                    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

                    # train the network
                    model_history = model.fit(x=x_train, y=y_train, batch_size=bs, epochs=ep)
                    index_acc = argmax(model_history.history['acc'])
                    mr['bloss'] = model_history.history['loss'][-1]
                    mr['baccuracy'] = model_history.history['acc'][-1]
                    mr['bepoch']= index_acc + 1
                    mr['xloss'] = model_history.history['loss'][index_acc]
                    mr['xaccuracy'] = model_history.history['acc'][index_acc]

                    # Evaluate the network                                                             
                    mr['yloss'], mr['yaccuracy'] = model.evaluate(x_test,y_test, batch_size=bs)
                    models_analysis.append(mr)
# Out:
# Epoch 1/25
# 41888/41888 [==============================] - 20s 482us/step - loss: 0.7775 - acc: 0.6692
# Epoch 2/25
# 41888/41888 [==============================] - 25s 607us/step - loss: 0.6564 - acc: 0.7112
# Epoch 3/25
# 41888/41888 [==============================] - 25s 596us/step - loss: 0.6219 - acc: 0.7272
# Epoch 4/25
# 41888/41888 [==============================] - 26s 627us/step - loss: 0.6013 - acc: 0.7378
# Epoch 5/25
# 41888/41888 [==============================] - 19s 463us/step - loss: 0.5878 - acc: 0.7426
# Epoch 6/25
# 41888/41888 [==============================] - 38s 900us/step - loss: 0.5782 - acc: 0.7486
# Epoch 7/25
# 41888/41888 [==============================] - 26s 625us/step - loss: 0.5717 - acc: 0.7525
# Epoch 8/25
# 41888/41888 [==============================] - 24s 574us/step - loss: 0.5641 - acc: 0.7547
# Epoch 9/25
# 41888/41888 [==============================] - 22s 518us/step - loss: 0.5586 - acc: 0.7579
# Epoch 10/25
# 41888/41888 [==============================] - 21s 499us/step - loss: 0.5546 - acc: 0.7595
# Epoch 11/25
# 41888/41888 [==============================] - 26s 610us/step - loss: 0.5508 - acc: 0.7603
# Epoch 12/25
# 41888/41888 [==============================] - 21s 504us/step - loss: 0.5481 - acc: 0.7635
# Epoch 13/25
# 41888/41888 [==============================] - 21s 513us/step - loss: 0.5437 - acc: 0.7645
# Epoch 14/25
# 41888/41888 [==============================] - 21s 506us/step - loss: 0.5414 - acc: 0.7659
# Epoch 15/25
# 41888/41888 [==============================] - 38s 901us/step - loss: 0.5400 - acc: 0.7668
# Epoch 16/25
# 41888/41888 [==============================] - 21s 493us/step - loss: 0.5365 - acc: 0.7672
# Epoch 17/25
# 41888/41888 [==============================] - 22s 518us/step - loss: 0.5357 - acc: 0.7692
# Epoch 18/25
# 41888/41888 [==============================] - 21s 499us/step - loss: 0.5334 - acc: 0.7689
# Epoch 19/25
# 41888/41888 [==============================] - 21s 490us/step - loss: 0.5317 - acc: 0.7703
# Epoch 20/25
# 41888/41888 [==============================] - 23s 557us/step - loss: 0.5305 - acc: 0.7694
# Epoch 21/25
# 41888/41888 [==============================] - 21s 493us/step - loss: 0.5298 - acc: 0.7727
# Epoch 22/25
# 41888/41888 [==============================] - 21s 491us/step - loss: 0.5272 - acc: 0.7716
# Epoch 23/25
# 41888/41888 [==============================] - 27s 637us/step - loss: 0.5257 - acc: 0.7722
# Epoch 24/25
# 41888/41888 [==============================] - 44s 1ms/step - loss: 0.5253 - acc: 0.7728
# Epoch 25/25
# 41888/41888 [==============================] - 21s 500us/step - loss: 0.5230 - acc: 0.7741
# 350/350 [==============================] - 0s 1ms/step
# Epoch 1/25
# 41888/41888 [==============================] - 14s 329us/step - loss: 0.7856 - acc: 0.66480s - loss:
# Epoch 2/25
# 41888/41888 [==============================] - 12s 280us/step - loss: 0.6695 - acc: 0.7042
# Epoch 3/25
# 41888/41888 [==============================] - 10s 248us/step - loss: 0.6327 - acc: 0.7221
# Epoch 4/25
# 41888/41888 [==============================] - 13s 304us/step - loss: 0.6136 - acc: 0.7306
# Epoch 5/25
# 41888/41888 [==============================] - 22s 528us/step - loss: 0.5970 - acc: 0.7385
# Epoch 6/25
# 41888/41888 [==============================] - 10s 251us/step - loss: 0.5849 - acc: 0.7429
# Epoch 7/25
# 41888/41888 [==============================] - 11s 271us/step - loss: 0.5741 - acc: 0.7484
# Epoch 8/25
# 41888/41888 [==============================] - 11s 269us/step - loss: 0.5666 - acc: 0.7519
# Epoch 9/25
# 41888/41888 [==============================] - 11s 256us/step - loss: 0.5597 - acc: 0.7540
# Epoch 10/25
# 41888/41888 [==============================] - 13s 311us/step - loss: 0.5554 - acc: 0.7583
# Epoch 11/25
# 41888/41888 [==============================] - 13s 312us/step - loss: 0.5510 - acc: 0.7591
# Epoch 12/25
# 41888/41888 [==============================] - 13s 308us/step - loss: 0.5441 - acc: 0.7625
# Epoch 13/25
# 41888/41888 [==============================] - 11s 267us/step - loss: 0.5414 - acc: 0.7645
# Epoch 14/25
# 41888/41888 [==============================] - 12s 288us/step - loss: 0.5390 - acc: 0.7651
# Epoch 15/25
# 41888/41888 [==============================] - 31s 743us/step - loss: 0.5350 - acc: 0.7675
# Epoch 16/25
# 41888/41888 [==============================] - 16s 388us/step - loss: 0.5339 - acc: 0.7675
# Epoch 17/25
# 41888/41888 [==============================] - 12s 278us/step - loss: 0.5299 - acc: 0.7689
# Epoch 18/25
# 41888/41888 [==============================] - 13s 321us/step - loss: 0.5272 - acc: 0.7702
# Epoch 19/25
# 41888/41888 [==============================] - 11s 258us/step - loss: 0.5266 - acc: 0.7723
# Epoch 20/25
# 41888/41888 [==============================] - 13s 306us/step - loss: 0.5257 - acc: 0.7715
# Epoch 21/25
# 41888/41888 [==============================] - 12s 282us/step - loss: 0.5238 - acc: 0.7728
# Epoch 22/25
# 41888/41888 [==============================] - 12s 281us/step - loss: 0.5212 - acc: 0.7732
# Epoch 23/25
# 41888/41888 [==============================] - 13s 303us/step - loss: 0.5207 - acc: 0.7752
# Epoch 24/25
# 41888/41888 [==============================] - 11s 266us/step - loss: 0.5198 - acc: 0.7749
# Epoch 25/25
# 41888/41888 [==============================] - 13s 318us/step - loss: 0.5185 - acc: 0.7739
# 350/350 [==============================] - 0s 1ms/step
# Epoch 1/25
# 41888/41888 [==============================] - 10s 231us/step - loss: 0.8205 - acc: 0.6597
# Epoch 2/25
# 41888/41888 [==============================] - 6s 147us/step - loss: 0.6943 - acc: 0.6991
# Epoch 3/25
# 41888/41888 [==============================] - 7s 158us/step - loss: 0.6563 - acc: 0.7128
# Epoch 4/25
# 41888/41888 [==============================] - 9s 210us/step - loss: 0.6328 - acc: 0.7234
# Epoch 5/25
# 41888/41888 [==============================] - 26s 628us/step - loss: 0.6174 - acc: 0.7296
# Epoch 6/25
# 41888/41888 [==============================] - 6s 148us/step - loss: 0.6055 - acc: 0.7349
# Epoch 7/25
# 41888/41888 [==============================] - 8s 201us/step - loss: 0.5944 - acc: 0.7395
# Epoch 8/25
# 41888/41888 [==============================] - 6s 150us/step - loss: 0.5873 - acc: 0.7450
# Epoch 9/25
# 41888/41888 [==============================] - 7s 166us/step - loss: 0.5778 - acc: 0.7478
# Epoch 10/25
# 41888/41888 [==============================] - 8s 195us/step - loss: 0.5726 - acc: 0.7505
# Epoch 11/25
# 41888/41888 [==============================] - 6s 144us/step - loss: 0.5664 - acc: 0.7532
# Epoch 12/25
# 41888/41888 [==============================] - 7s 168us/step - loss: 0.5620 - acc: 0.7549
# Epoch 13/25
# 41888/41888 [==============================] - 6s 151us/step - loss: 0.5590 - acc: 0.7557
# Epoch 14/25
# 41888/41888 [==============================] - 7s 167us/step - loss: 0.5538 - acc: 0.7581 0s - loss: 0.5547 - a - ETA: 0s - loss:
# Epoch 15/25
# 41888/41888 [==============================] - 11s 265us/step - loss: 0.5489 - acc: 0.7627
# Epoch 16/25
# 41888/41888 [==============================] - 8s 181us/step - loss: 0.5472 - acc: 0.7619
# Epoch 17/25
# 41888/41888 [==============================] - 6s 151us/step - loss: 0.5447 - acc: 0.7642
# Epoch 18/25
# 41888/41888 [==============================] - 7s 168us/step - loss: 0.5400 - acc: 0.7655
# Epoch 19/25
# 41888/41888 [==============================] - 6s 148us/step - loss: 0.5378 - acc: 0.7681
# Epoch 20/25
# 41888/41888 [==============================] - 6s 146us/step - loss: 0.5337 - acc: 0.7697
# Epoch 21/25
# 41888/41888 [==============================] - 7s 171us/step - loss: 0.5332 - acc: 0.7690
# Epoch 22/25
# 41888/41888 [==============================] - 6s 145us/step - loss: 0.5315 - acc: 0.7718
# Epoch 23/25
# 41888/41888 [==============================] - 7s 171us/step - loss: 0.5284 - acc: 0.7716
# Epoch 24/25
# 41888/41888 [==============================] - 6s 150us/step - loss: 0.5259 - acc: 0.7731
# Epoch 25/25
# 41888/41888 [==============================] - 6s 149us/step - loss: 0.5255 - acc: 0.7734
# 350/350 [==============================] - 0s 1ms/step
# Epoch 1/25
# 41888/41888 [==============================] - 42s 1ms/step - loss: 0.7541 - acc: 0.6755
# Epoch 2/25
# 41888/41888 [==============================] - 42s 1ms/step - loss: 0.6406 - acc: 0.7161
# Epoch 3/25
# 41888/41888 [==============================] - 57s 1ms/step - loss: 0.6126 - acc: 0.7323
# Epoch 4/25
# 41888/41888 [==============================] - 50s 1ms/step - loss: 0.5972 - acc: 0.7389
# Epoch 5/25
# 41888/41888 [==============================] - 36s 860us/step - loss: 0.5829 - acc: 0.7459
# Epoch 6/25
# 41888/41888 [==============================] - 35s 847us/step - loss: 0.5747 - acc: 0.7482
# Epoch 7/25
# 41888/41888 [==============================] - 34s 810us/step - loss: 0.5644 - acc: 0.7553
# Epoch 8/25
# 41888/41888 [==============================] - 34s 817us/step - loss: 0.5601 - acc: 0.7569
# Epoch 9/25
# 41888/41888 [==============================] - 59s 1ms/step - loss: 0.5539 - acc: 0.7588
# Epoch 10/25
# 41888/41888 [==============================] - 38s 916us/step - loss: 0.5526 - acc: 0.7591
# Epoch 11/25
# 41888/41888 [==============================] - 36s 871us/step - loss: 0.5481 - acc: 0.7629
# Epoch 12/25
# 41888/41888 [==============================] - 46s 1ms/step - loss: 0.5454 - acc: 0.7647
# Epoch 13/25
# 41888/41888 [==============================] - 55s 1ms/step - loss: 0.5411 - acc: 0.7652
# Epoch 14/25
# 41888/41888 [==============================] - 37s 884us/step - loss: 0.5399 - acc: 0.7652
# Epoch 15/25
# 41888/41888 [==============================] - 37s 877us/step - loss: 0.5368 - acc: 0.7671
# Epoch 16/25
# 41888/41888 [==============================] - 36s 852us/step - loss: 0.5340 - acc: 0.7695
# Epoch 17/25
# 41888/41888 [==============================] - 36s 853us/step - loss: 0.5340 - acc: 0.7692
# Epoch 18/25
# 41888/41888 [==============================] - 62s 1ms/step - loss: 0.5320 - acc: 0.7707
# Epoch 19/25
# 41888/41888 [==============================] - 51s 1ms/step - loss: 0.5298 - acc: 0.7713
# Epoch 20/25
# 41888/41888 [==============================] - 37s 873us/step - loss: 0.5265 - acc: 0.7723
# Epoch 21/25
# 41888/41888 [==============================] - 36s 866us/step - loss: 0.5261 - acc: 0.7721
# Epoch 22/25
# 41888/41888 [==============================] - 36s 849us/step - loss: 0.5241 - acc: 0.7714
# Epoch 23/25
# 41888/41888 [==============================] - 50s 1ms/step - loss: 0.5225 - acc: 0.7748
# Epoch 24/25
# 41888/41888 [==============================] - 42s 1ms/step - loss: 0.5227 - acc: 0.7751
# Epoch 25/25
# 41888/41888 [==============================] - 36s 871us/step - loss: 0.5205 - acc: 0.7745
# 350/350 [==============================] - 1s 2ms/step
# Epoch 1/25
# 41888/41888 [==============================] - 22s 517us/step - loss: 0.7546 - acc: 0.6762
# Epoch 2/25
# 41888/41888 [==============================] - 29s 700us/step - loss: 0.6452 - acc: 0.7158
# Epoch 3/25
# 41888/41888 [==============================] - 21s 496us/step - loss: 0.6149 - acc: 0.7297
# Epoch 4/25
# 41888/41888 [==============================] - 27s 649us/step - loss: 0.5952 - acc: 0.7405
# Epoch 5/25
# 41888/41888 [==============================] - 20s 472us/step - loss: 0.5830 - acc: 0.7446
# Epoch 6/25
# 41888/41888 [==============================] - 18s 436us/step - loss: 0.5724 - acc: 0.7495
# Epoch 7/25
# 41888/41888 [==============================] - 18s 438us/step - loss: 0.5654 - acc: 0.7535
# Epoch 8/25
# 41888/41888 [==============================] - 16s 392us/step - loss: 0.5597 - acc: 0.7557
# Epoch 9/25
# 41888/41888 [==============================] - 29s 683us/step - loss: 0.5534 - acc: 0.7582
# Epoch 10/25
# 41888/41888 [==============================] - 19s 453us/step - loss: 0.5491 - acc: 0.76051s - loss: 0.5500 - acc: - ETA: 0s - loss: 0.5
# Epoch 11/25
# 41888/41888 [==============================] - 18s 439us/step - loss: 0.5438 - acc: 0.7638
# Epoch 12/25
# 41888/41888 [==============================] - 17s 401us/step - loss: 0.5407 - acc: 0.7653
# Epoch 13/25
# 41888/41888 [==============================] - 36s 852us/step - loss: 0.5380 - acc: 0.7654
# Epoch 14/25
# 41888/41888 [==============================] - 19s 447us/step - loss: 0.5341 - acc: 0.7695
# Epoch 15/25
# 41888/41888 [==============================] - 18s 428us/step - loss: 0.5325 - acc: 0.7681
# Epoch 16/25
# 41888/41888 [==============================] - 37s 875us/step - loss: 0.5281 - acc: 0.7700
# Epoch 17/25
# 41888/41888 [==============================] - 21s 497us/step - loss: 0.5266 - acc: 0.7724
# Epoch 18/25
# 41888/41888 [==============================] - 18s 423us/step - loss: 0.5244 - acc: 0.7738
# Epoch 19/25
# 41888/41888 [==============================] - 21s 497us/step - loss: 0.5219 - acc: 0.7756
# Epoch 20/25
# 41888/41888 [==============================] - 34s 819us/step - loss: 0.5205 - acc: 0.77463s - loss: 0.5216 - acc - ETA: - ETA: 1s - loss: 0.5218 - acc:  - ETA: 0s - loss: 0.52
# Epoch 21/25
# 41888/41888 [==============================] - 36s 854us/step - loss: 0.5189 - acc: 0.7760
# Epoch 22/25
# 41888/41888 [==============================] - 22s 530us/step - loss: 0.5158 - acc: 0.7748
# Epoch 23/25
# 41888/41888 [==============================] - 21s 506us/step - loss: 0.5149 - acc: 0.7754
# Epoch 24/25
# 41888/41888 [==============================] - 35s 836us/step - loss: 0.5161 - acc: 0.7744
# Epoch 25/25
# 41888/41888 [==============================] - 17s 405us/step - loss: 0.5120 - acc: 0.7785
# 350/350 [==============================] - 0s 1ms/step
# Epoch 1/25
# 41888/41888 [==============================] - 10s 249us/step - loss: 0.7876 - acc: 0.6678
# Epoch 2/25
# 41888/41888 [==============================] - 11s 265us/step - loss: 0.6614 - acc: 0.7099
# Epoch 3/25
# 41888/41888 [==============================] - 11s 264us/step - loss: 0.6289 - acc: 0.7242
# Epoch 4/25
# 41888/41888 [==============================] - 11s 254us/step - loss: 0.6093 - acc: 0.7324
# Epoch 5/25
# 41888/41888 [==============================] - 10s 232us/step - loss: 0.5966 - acc: 0.7393
# Epoch 6/25
# 41888/41888 [==============================] - 10s 230us/step - loss: 0.5842 - acc: 0.7449
# Epoch 7/25
# 41888/41888 [==============================] - 26s 611us/step - loss: 0.5773 - acc: 0.7475
# Epoch 8/25
# 41888/41888 [==============================] - 10s 233us/step - loss: 0.5697 - acc: 0.7491
# Epoch 9/25
# 41888/41888 [==============================] - 9s 223us/step - loss: 0.5621 - acc: 0.7541
# Epoch 10/25
# 41888/41888 [==============================] - 9s 225us/step - loss: 0.5586 - acc: 0.7573
# Epoch 11/25
# 41888/41888 [==============================] - 10s 228us/step - loss: 0.5506 - acc: 0.7606
# Epoch 12/25
# 41888/41888 [==============================] - 9s 220us/step - loss: 0.5458 - acc: 0.7631
# Epoch 13/25
# 41888/41888 [==============================] - 13s 304us/step - loss: 0.5427 - acc: 0.76260s - loss:
# Epoch 14/25
# 41888/41888 [==============================] - 15s 354us/step - loss: 0.5408 - acc: 0.7643
# Epoch 15/25
# 41888/41888 [==============================] - 13s 303us/step - loss: 0.5371 - acc: 0.7655
# Epoch 16/25
# 41888/41888 [==============================] - 10s 250us/step - loss: 0.5319 - acc: 0.7687
# Epoch 17/25
# 41888/41888 [==============================] - 11s 271us/step - loss: 0.5285 - acc: 0.7707
# Epoch 18/25
# 41888/41888 [==============================] - 10s 235us/step - loss: 0.5271 - acc: 0.7704
# Epoch 19/25
# 41888/41888 [==============================] - 9s 225us/step - loss: 0.5250 - acc: 0.7730
# Epoch 20/25
# 41888/41888 [==============================] - 10s 228us/step - loss: 0.5227 - acc: 0.7727
# Epoch 21/25
# 41888/41888 [==============================] - 9s 217us/step - loss: 0.5204 - acc: 0.7734
# Epoch 22/25
# 41888/41888 [==============================] - 14s 344us/step - loss: 0.5179 - acc: 0.7768
# Epoch 23/25
# 41888/41888 [==============================] - 11s 273us/step - loss: 0.5184 - acc: 0.7743
# Epoch 24/25
# 41888/41888 [==============================] - 11s 265us/step - loss: 0.5141 - acc: 0.7780
# Epoch 25/25
# 41888/41888 [==============================] - 10s 248us/step - loss: 0.5148 - acc: 0.7781
# 350/350 [==============================] - 0s 1ms/step

# %% [markdown]
# ### CNN best network

# %%
best_model = None

for itera in models_analysis:
    if best_model is None:
        best_model = itera
    elif itera['baccuracy'] > best_model['baccuracy']:
        best_model = itera

print (best_model)
# Out:
# {'conf': [256, 16, 2, 2, 25, 0.05], 'xaccuracy': 0.7785045836516424, 'yaccuracy': 0.797142857824053, 'xloss': 0.5120050630911422, 'yloss': 0.5152610652787345, 'bepoch': 25, 'baccuracy': 0.7785045836516424, 'bloss': 0.5120050630911422}
